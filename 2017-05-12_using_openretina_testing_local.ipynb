# %% [markdown]
# # testing locally without network
#
#
# Launching on the same computer
# - a client grabbing the display and sending it over the network (stays in the localhost),
# - a server displaying it on the host's display

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile 2017-05-12_using_openretina_testing_camera.py
#! /usr/bin/env python3
# -*- coding: utf8 -*-
from __future__ import division, print_function
"""
openRetina : a photoreceptor layer
See https://github.com/laurentperrinet/openRetina
"""
__author__ = "(c) Pierre Albiges, Victor Boutin & Laurent Perrinet INT - CNRS"

from openRetina import openRetina
phrs = openRetina(model=dict(layer='phrs', # label for this layer
                             input=['camera'], # input: can be the camera, noise, a movie (TODO)
                             output=['stream'] # output: can be stream, display, ...
                             ))
phrs.run()
# Out:
# Overwriting 2017-05-12_using_openretina_testing_camera.py

# %% [raw]
# !ipython3 2017-05-12_using_openretina_testing_camera.py &

# %%
# !chmod +x 2017-05-12_using_openretina_testing_camera.py

# %%
# %%writefile 2017-05-12_using_openretina_testing_camera_srv.py
"""
openRetina : a basic thalamic layer
See https://github.com/laurentperrinet/openRetina
"""
__author__ = "(c) Victor Boutin & Laurent Perrinet INT - CNRS"

import subprocess
p = subprocess.Popen(['./2017-05-12_using_openretina_testing_camera.py'])

from openRetina import openRetina
camera = openRetina(model=dict(layer='camera', # label for this layer
                                 input=['stream'], # input: can be the camera, noise, a movie (TODO)
                                 output=['display'], # output: can be stream, display, capture,...
                                 T_SIM=20))
camera.run()
# Out:
# Overwriting 2017-05-12_using_openretina_testing_camera_srv.py

# %%
# !ipython3 2017-05-12_using_openretina_testing_camera_srv.py
# Out:
# Connecting to retina with port 5566
# 2017-05-11 15:43:15.889 Python[55865:4768552] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/px/n031whw95_39ccwg0wqwt5jw0000gn/T/org.python.python.savedState
# top  0.00832676887512207
# /usr/local/lib/python3.6/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated since IPython 4.0. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# 0.026227951049804688
# Sending request
# dim1 : 720, dim2 : 1280
# Using OpenCV
# Running retina on port:  5566
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 1.9160656929016113
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 2.09855580329895
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 2.231886863708496
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 2.365450859069824
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 2.519585609436035
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 2.691241979598999
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 2.828002691268921
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 2.986879825592041
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 3.1255438327789307
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 3.2851078510284424
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 3.412956953048706
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 3.583828926086426
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 3.711554765701294
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 3.8830037117004395
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 4.050658702850342
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 4.182708978652954
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 4.346108913421631
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 4.475629806518555
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 4.639876842498779
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 4.7739787101745605
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 4.926028728485107
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 5.064343690872192
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 5.191248893737793
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 5.328390836715698
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 5.494793891906738
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 5.633691787719727
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 5.786697864532471
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 5.920621633529663
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 6.085320949554443
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 6.221467733383179
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 6.348835706710815
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 6.4891698360443115
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 6.644743919372559
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 6.7774248123168945
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 6.946617841720581
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 7.082328796386719
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 7.243460655212402
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 7.376126766204834
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 7.545027732849121
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 7.712955713272095
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 7.851100921630859
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 8.01216173171997
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 8.14630675315857
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 8.291838884353638
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 8.431641817092896
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 8.590051651000977
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 8.726917743682861
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 8.860296964645386
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 8.988614797592163
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 9.153743743896484
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 9.292974710464478
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 9.446597814559937
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 9.587393045425415
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 9.75844669342041
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 9.88198184967041
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 10.020055055618286
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 10.146934747695923
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 10.319484949111938
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 10.44942593574524
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 10.620435953140259
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 10.743654727935791
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 10.901679754257202
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 11.036893844604492
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 11.201561689376831
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 11.366667032241821
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 11.502546787261963
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 11.668015718460083
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 11.798244714736938
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 11.960614919662476
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 12.104087829589844
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 12.257454872131348
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 12.391632795333862
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 12.528141736984253
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 12.660869836807251
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 12.821010828018188
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 12.948031902313232
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 13.124860763549805
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 13.249157905578613
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 13.411202669143677
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 13.547385692596436
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 13.677037715911865
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 13.815592765808105
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 13.976688861846924
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 14.116511821746826
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 14.272928953170776
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 14.401262760162354
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 14.570626735687256
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 14.701346635818481
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 14.874205827713013
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 15.028435945510864
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 15.1664719581604
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 15.32037878036499
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 15.468626737594604
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 15.6261146068573
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 15.76749587059021
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 15.92123794555664
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 16.04964280128479
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 16.184854984283447
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 16.325018882751465
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 16.485200881958008
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 16.61199164390564
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 16.7795147895813
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 16.921074867248535
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 17.080094814300537
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 17.212324857711792
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 17.345568895339966
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 17.475980043411255
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 17.64126491546631
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 17.77340078353882
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 17.93983483314514
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 18.071995735168457
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 18.2373628616333
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 18.36963200569153
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 18.526923894882202
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 18.697612762451172
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 18.838303804397583
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 18.997068643569946
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 19.130615711212158
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 19.292536735534668
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 19.4127938747406
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 19.58696985244751
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 19.71169376373291
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 19.848357677459717
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 19.981002807617188
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 20.149333953857422
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 20.28330969810486
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# 20.447707891464233
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Received request b'RIP'
