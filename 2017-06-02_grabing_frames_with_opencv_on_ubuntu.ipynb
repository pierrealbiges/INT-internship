# %% [markdown]
# File name : 2017-05-05_grabing_frames_with_opencv_on_ubuntu.ipynb
# Authors : Pierre Albiges, Victor Boutin and Laurent Perrinet
# Date created : 2017-04-25
# Date last modified : 2017-05-04
# Object : Apprehend the OpenRetina project through the manipulation of the PhotoReceptor class
#
# See https://github.com/laurentperrinet/openRetina/blob/master/src/openRetina.py as source for the program
# See https://github.com/pierrealbiges/INT-internship/ for associated documents

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import time

# %%
from openRetina import PhotoReceptor

# %% [markdown]
# # Grabbing one frame and exiting

# %%
Ph = PhotoReceptor(w=1280, h=720, DOWNSCALE=0)
frame = Ph.grab()
Ph.close()

plt.imshow(frame)
# Out:
# Capture released

# %% [markdown]
# # Benchmarking camera for different sizes

# %%
import numpy as np

downscales = 1.5**np.arange(16) # [1, 1.25, 1.5, 2, 3, 4, 6, 6.5]

# %%
'''  Version a : Run the program and calculate the framerate (limit = number of frames recorded) '''

num_frames = 50
sizes_a, frames_a = [], []
for ds in downscales:
    
    Ph = PhotoReceptor(w=1280, h=720, DOWNSCALE = ds, verbose=True)
    frame = Ph.grab()

    time.sleep(1)
    start = time.time()

    for i in range(num_frames):
        frame = Ph.grab()

    seconds = time.time() - start
        
    sizes_a.append(Ph.h*Ph.w)
    Ph.close()

    fps = num_frames / seconds
    frames_a.append(fps)
    print ('Frame rate : %s \n' % fps)
# Out:
# Before a downscale of 1.0 dim1 : 720, dim2 : 1280
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Using OpenCV
# After a downscale of 1.0, dim1 : 720, dim2 : 1280
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture grabbed (720, 1280, 3)
# Capture released
# Frame rate : 29.99511559868958
#
# Before a downscale of 1.5 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 1.5, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.954050931050688
#
# Before a downscale of 2.25 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 2.25, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.954127942419113
#
# Before a downscale of 3.375 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 3.375, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.84880123121295
#
# Before a downscale of 5.0625 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 5.0625, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.831189327552448
#
# Before a downscale of 7.59375 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 7.59375, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.813030264216422
#
# Before a downscale of 11.390625 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 11.390625, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.963676140855362
#
# Before a downscale of 17.0859375 dim1 : 720, dim2 : 1280
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Using OpenCV
# After a downscale of 17.0859375, dim1 : 544, dim2 : 960
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture released
# Frame rate : 29.986070427984743
#
# Before a downscale of 25.62890625 dim1 : 720, dim2 : 1280
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Using OpenCV
# After a downscale of 25.62890625, dim1 : 544, dim2 : 960
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture released
# Frame rate : 29.906580439661894
#
# Before a downscale of 38.443359375 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 38.443359375, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.848482605730265
#
# Before a downscale of 57.6650390625 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 57.6650390625, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.97462275376353
#
# Before a downscale of 86.49755859375 dim1 : 720, dim2 : 1280
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Using OpenCV
# After a downscale of 86.49755859375, dim1 : 544, dim2 : 960
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture grabbed (544, 960, 3)
# Capture released
# Frame rate : 29.908316333748626
#
# Before a downscale of 129.746337890625 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 129.746337890625, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.95654544501387
#
# Before a downscale of 194.6195068359375 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 194.6195068359375, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.849893106128107
#
# Before a downscale of 291.92926025390625 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 291.92926025390625, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.91049181721379
#
# Before a downscale of 437.8938903808594 dim1 : 720, dim2 : 1280
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Using OpenCV
# After a downscale of 437.8938903808594, dim1 : 576, dim2 : 1024
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture grabbed (576, 1024, 3)
# Capture released
# Frame rate : 29.881588006511063

# %%
''' Version b : Run the program and calculate the framerate (limit = time recorded) '''

sizes_b, frames_b = [], []
for ds in downscales:
    Ph = PhotoReceptor(w=1280, h=720, DOWNSCALE = ds)
    Rec = True
    nb_frames = 0

    start = time.time()

    while(Rec == True):

        frame = Ph.grab()
        nb_frames += 1
        
        seconds = time.time() - start
        
        if seconds >= 10 :
            Rec = False
    sizes_b.append(Ph.h*Ph.w)
           
    Ph.close()

    fps = nb_frames / seconds
    frames_b.append(fps)
    print ('Frame rate %s \n' % fps)
# Out:
# Capture released
# Frame rate 29.998766234594473
#
# Capture released
# Frame rate 29.993754971929317
#
# Capture released
# Frame rate 29.989878255925397
#
# Capture released
# Frame rate 30.007735405602993
#
# Capture released
# Frame rate 29.99297640289714
#
# Capture released
# Frame rate 30.005658573657453
#
# Capture released
# Frame rate 29.989515870303958
#
# Capture released
# Frame rate 29.990373601918158
#
# Capture released
# Frame rate 29.99030498158347
#
# Capture released
# Frame rate 29.995875687239447
#
# Capture released
# Frame rate 29.992255779979295
#
# Capture released
# Frame rate 30.006754722826265
#
# Capture released
# Frame rate 30.000856287737204
#
# Capture released
# Frame rate 30.006541477383625
#
# Capture released
# Frame rate 30.003463663380135
#
# Capture released
# Frame rate 30.00958996279529

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(sizes_a, frames_a, 'b', marker='o', label='method a')
ax.plot(sizes_b, frames_b, 'r', marker='o', label='method b')
ax.grid(linestyle='--')
plt.legend()
ax.set_title('Effect of downscale on framerate, per method used')
ax.set_xlabel('# of pixels')
ax.set_ylabel('Framerate')
ax.set_ylim(0, 1.1*max(max(frames_a), max(frames_b)))
plt.show()

# %% [markdown]
# # 2017-06-02 : Rebuilding a FR version for my poster

# %%
import matplotlib.pyplot as plt

sizes = [(720.0*1280.0),(576.0*1024.0),(480.0*720.0),(480.0*640.0),(288.0*352.0),(240.0*320.0),(144.0*176.0),(120.0*160.0)]
frames_a = [18.4494002708,19.4611137687,18.472009579,18.2200675197,18.2392351522,18.2156204866,18.2304703399,18.2026810597]
frames_b = [13.0453401299,13.0462340644,13.3746203564,13.2597223238,13.2618059846,13.2625967492,13.263489468,13.2642898953]

fig, ax = plt.subplots(figsize=(8,5))
ax.plot(sizes, frames_a, 'b', marker='o', label='méthode a')
ax.plot(sizes, frames_b, 'r', marker='o', label='méthode b')
ax.grid(linestyle='--')
plt.legend(loc=3)
ax.set_title("Etalonnage des performances d'enregistrement de la caméra")
ax.set_xlabel('Résolution de la caméra (Nombre de pixels)')
ax.set_ylabel('Framerate')
ax.set_ylim(0, 1.1*max(max(frames_a), max(frames_b)))
#plt.show(fig)
plt.savefig('benchmark_fig.png', dpi=1000)
