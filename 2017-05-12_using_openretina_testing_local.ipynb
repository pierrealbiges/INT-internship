# %% [markdown]
# # testing with noise
#
#
# Launching on the same computer
# - a client grabbing the display and sending it over the network (stays in the localhost),
# - a server displaying it on the host's display

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile 2017-05-12_using_openretina_testing_camera.py
#! /usr/bin/env python3
# -*- coding: utf8 -*-
from __future__ import division, print_function
"""
openRetina : a photoreceptor layer
See https://github.com/laurentperrinet/openRetina
"""
__author__ = "(c) Pierre Albiges, Victor Boutin & Laurent Perrinet INT - CNRS"

from openRetina import openRetina
phrs = openRetina(model=dict(layer='phrs', # label for this layer
                             input=['camera'], # input: can be the camera, noise, a movie (TODO)
                             output=['stream'] # output: can be stream, display, ...
                             ))
phrs.run()
# Out:
# Overwriting 2017-05-12_using_openretina_testing_camera.py

# %% [raw]
# !ipython3 2017-05-12_using_openretina_testing_camera.py &

# %%
# !chmod +x 2017-05-12_using_openretina_testing_camera.py

# %%
# %%writefile 2017-05-12_using_openretina_testing_camera_srv.py
"""
openRetina : a basic thalamic layer
See https://github.com/laurentperrinet/openRetina
"""
__author__ = "(c) Victor Boutin & Laurent Perrinet INT - CNRS"

import subprocess
p = subprocess.Popen(['./2017-05-12_using_openretina_testing_camera.py'])

from openRetina import openRetina
camera = openRetina(model=dict(layer='camera', # label for this layer
                                 input=['stream'], # input: can be the camera, noise, a movie (TODO)
                                 output=['display'], # output: can be stream, display, capture,...
                                 T_SIM=20))
camera.run()
# Out:
# Overwriting 2017-05-12_using_openretina_testing_camera_srv.py

# %%
# !ipython3 2017-05-12_using_openretina_testing_camera_srv.py
# Out:
# Connecting to retina with port 5566
# 1280
# 720
# 2017-05-11 14:16:40.523 Python[54732:4490986] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/px/n031whw95_39ccwg0wqwt5jw0000gn/T/org.python.python.savedState
# /usr/local/lib/python3.6/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated since IPython 4.0. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# Sending request
# dim1 : 720, dim2 : 1280
# Using OpenCV
# Running retina on port:  5566
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Sending request
# Received request b'REQ'
# Image   (720, 1280, 3) 0 1
# Received request b'RIP'
